# %%
import pyautogui

area = pyautogui.screenshot(region=(400, 181, 700, 700))
area.save(r".\area-mine.png")

# canto superior esquerdo: (400, 181)
# canto inferior esquerdo: (400, 881)
# altura: 700

# canto superior direito: (1102, 180)
# largura: 700

# %%
# marrom_1 (68, 64, 60)
# marrom_2 (87, 83, 78)

# ignore_1 (55, 65, 81)
# ignore_2 (75, 85, 99)

# flag_1 (2, 6, 23)
# flag_2 (30, 41, 59)

# target_1 (69, 74, 81)
# target_2 (59, 64, 72)

# distância entre os quadrados em x: 28
# distância entre os quadrados em y: 28

# tabuleiro: 15x15

# %%
import pyautogui
import time

# Função para clicar com o botão esquerdo do mouse
def click_left(x, y):
    pyautogui.click(x, y)

# Função para verificar se a cor é igual a um dos alvos
def is_color_equal(color, target_color):
    return color == target_color

# Função para reiniciar o jogo
def reinicia():
    color = pyautogui.pixel(778, 611)
    if is_color_equal(color, (113, 63, 18)):
        click_left(778, 611)
        time.sleep(0.01)
        click_left(745, 217)
        time.sleep(0.01)
        click_left(759, 375)
        return True
    else:
        return False

# Cores
ignore_1 = (55, 65, 81)
ignore_2 = (75, 85, 99)
flag_1 = (2, 6, 23)
flag_2 = (30, 41, 59)
target_1 = (87, 83, 78)
target_2 = (68, 64, 60)

# Distâncias
square_distance_x = 14
square_distance_y = 14

# Tamanho do tabuleiro
board_size_x = 51 
board_size_y = 51

# Posição inicial do mouse
start_x = 404
start_y = 186

# Contador de iterações
iteration_counter = 0

# Última posição clicada
last_clicked_position = None

time.sleep(2)

while True:
    # Inicializa o contador para a iteração atual
    current_iteration_counter = 0

    for y in range(board_size_y):
        for x in range(board_size_x):
            # Calcula as coordenadas do centro do quadrado
            square_center_x = start_x + x * square_distance_x
            square_center_y = start_y + y * square_distance_y

            # Obtém a cor do quadrado no centro diretamente da imagem capturada
            color = pyautogui.pixel(square_center_x, square_center_y)

            # Verifica se a cor do quadrado é igual a um dos alvos
            if is_color_equal(color, target_1) or is_color_equal(color, target_2):
                click_left(square_center_x, square_center_y)
                current_iteration_counter += 1

                # Atualiza a última posição clicada
                last_clicked_position = (square_center_x, square_center_y)

    # Verifica se o contador da iteração atual é maior que 1
    if current_iteration_counter > 1:
        # Incrementa o contador global
        iteration_counter += 1

        # Verifica se a última posição clicada se repetiu 5 vezes
        if last_clicked_position is not None and iteration_counter == 30:
            last_clicked_position = None
            iteration_counter = 0  # Zera o contador ao reiniciar o jogo
            click_left(745, 217)
            time.sleep(0.3)
            click_left(945, 586)
            time.sleep(0.3)
            click_left(759, 375)

        # Verifica se a última posição clicada se repetiu 8 vezes e clica no quadrado ao redor
        elif last_clicked_position is not None and (iteration_counter == 18 or iteration_counter == 22):
            click_left(last_clicked_position[0] - square_distance_x, last_clicked_position[1] + square_distance_y)
            click_left(last_clicked_position[0] + square_distance_x, last_clicked_position[1] - square_distance_y)
            last_clicked_position = None
        elif last_clicked_position is not None and (iteration_counter == 16 or iteration_counter == 20):
            click_left(last_clicked_position[0] - square_distance_x, last_clicked_position[1] - square_distance_y)
            click_left(last_clicked_position[0] + square_distance_x, last_clicked_position[1] + square_distance_y)
            last_clicked_position = None
    else:
        if reinicia():
            last_clicked_position = None
            iteration_counter = 0  # Zera o contador ao reiniciar o jogo
            print("Jogo reiniciado!")
        else:
            last_clicked_position = None
            iteration_counter = 0  # Zera o contador ao reiniciar o jogo
            click_left(745, 217)
            time.sleep(0.3)
            click_left(945, 586)
            time.sleep(0.3)
            click_left(759, 375)
    print("Iteração: " + str(iteration_counter))
# Out:
# Iteração: 1
# Iteração: 2
# Iteração: 3
# Iteração: 4
# Iteração: 5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\pablo\Repositorio\ia-opencv-deteccao-objetos\minesweeper-bot-myt.ipynb Cell 3 line 6
#      <a href='vscode-notebook-cell:/c%3A/Users/pablo/Repositorio/ia-opencv-deteccao-objetos/minesweeper-bot-myt.ipynb#W2sZmlsZQ%3D%3D?line=60'>61</a> square_center_y = start_y + y * square_distance_y
#      <a href='vscode-notebook-cell:/c%3A/Users/pablo/Repositorio/ia-opencv-deteccao-objetos/minesweeper-bot-myt.ipynb#W2sZmlsZQ%3D%3D?line=62'>63</a> # Obtém a cor do quadrado no centro diretamente da imagem capturada
# ---> <a href='vscode-notebook-cell:/c%3A/Users/pablo/Repositorio/ia-opencv-deteccao-objetos/minesweeper-bot-myt.ipynb#W2sZmlsZQ%3D%3D?line=63'>64</a> color = pyautogui.pixel(square_center_x, square_center_y)
#      <a href='vscode-notebook-cell:/c%3A/Users/pablo/Repositorio/ia-opencv-deteccao-objetos/minesweeper-bot-myt.ipynb#W2sZmlsZQ%3D%3D?line=65'>66</a> # Verifica se a cor do quadrado é igual a um dos alvos
#      <a href='vscode-notebook-cell:/c%3A/Users/pablo/Repositorio/ia-opencv-deteccao-objetos/minesweeper-bot-myt.ipynb#W2sZmlsZQ%3D%3D?line=66'>67</a> if is_color_equal(color, target_1) or is_color_equal(color, target_2):
#
# File c:\Users\pablo\anaconda3\Lib\site-packages\pyscreeze\__init__.py:757, in pixel(x, y)
#     754 if sys.platform == 'win32':
#     755     # On Windows, calling GetDC() and GetPixel() is twice as fast as using our screenshot() function.
#     756     with __win32_openDC() as hdc:  # handle will be released automatically
# --> 757         color = windll.gdi32.GetPixel(hdc, x, y)
#     758         if color < 0:
#     759             raise WindowsError("windll.gdi32.GetPixel failed : return {}".format(color))
#
# KeyboardInterrupt:
